# %%
a = 10
b = 20
print('This is a string {} and {}'.format(a,b))
# Out:
# This is a string 10 and 20

# %%
print('The {0} {1} {0}'.format('fox','quick'))
# Out:
# The fox quick fox

# %%
print('The {q} {b} {q}'.format(q='fox',b='quick'))
# Out:
# The fox quick fox

# %%
res = 100/77
print(res)
print('The result was {r:20.09f}'.format(r=res))
# Out:
# 1.2987012987012987
# The result was          1.298701299

# %%
print(f"Hello World is {a + b}")
# Out:
# Hello World is 30
